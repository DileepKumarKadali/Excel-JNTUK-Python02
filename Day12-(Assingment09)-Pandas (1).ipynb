# %% [markdown]
# # Day12 Assignment09 Submitted by Mr. Dileep Kumar Kadali
# ## Assistant Professor, CSE Department,
# ### Swarnandhra College of Engineering and Technology (A2)
#
#
# # Assignment questions for Pandas

# %% [markdown]
# ### 1) Write a Pandas program to select the specified columns and rows from a given data frame. Go to the editor
# Sample Python dictionary data and list labels:
#
# Select 'name' and 'score' columns in rows 1, 3, 5, 6 from the following data frame.
# exam_data = {'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'],
# 'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],
# 'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
# 'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']}
# labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']
#
# ### Expected Output:
# Select specific columns and rows:
# name score
# b Dima 9.0
# d James NaN
# f Michael 20.0
# g Matthew 14.5

# %%
import pandas as pd
import numpy as np

# %%
exam_data  = {'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'],
        'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],
        'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
        'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']}
labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

# %%
df = pd.DataFrame(exam_data , index=labels)

# %%
df
# Out:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
# d      James    NaN         3      no
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# h      Laura    NaN         1      no
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes

# %%
print("Select specific columns and rows:")
print(df.iloc[[1, 3, 5, 6], [0, 1]])
# Out:
# Select specific columns and rows:
#       name  score
# b     Dima    9.0
# d    James    NaN
# f  Michael   20.0
# g  Matthew   14.5

# %% [markdown]
# # 2)Use Crime dataset

# %%
c_data = pd.read_csv('crime_data.csv',index_col=0)
c_data
# Out:
#                 Murder  Assault  UrbanPop  Rape
# Alabama           13.2      236        58  21.2
# Alaska            10.0      263        48  44.5
# Arizona            8.1      294        80  31.0
# Arkansas           8.8      190        50  19.5
# California         9.0      276        91  40.6
# Colorado           7.9      204        78  38.7
# Connecticut        3.3      110        77  11.1
# Delaware           5.9      238        72  15.8
# Florida           15.4      335        80  31.9
# Georgia           17.4      211        60  25.8
# Hawaii             5.3       46        83  20.2
# Idaho              2.6      120        54  14.2
# Illinois          10.4      249        83  24.0
# Indiana            7.2      113        65  21.0
# Iowa               2.2       56        57  11.3
# Kansas             6.0      115        66  18.0
# Kentucky           9.7      109        52  16.3
# Louisiana         15.4      249        66  22.2
# Maine              2.1       83        51   7.8
# ...

# %% [markdown]
# ### I) find the aggregations like all moments of business decisions for all columns,value counts, missing values.

# %%
c_data.columns
# Out:
# Index(['Murder', 'Assault', 'UrbanPop', 'Rape'], dtype='object')

# %%
c_data.isna().count
# Out:
# <bound method DataFrame.count of                 Murder  Assault  UrbanPop   Rape
# Alabama          False    False     False  False
# Alaska           False    False     False  False
# Arizona          False    False     False  False
# Arkansas         False    False     False  False
# California       False    False     False  False
# Colorado         False    False     False  False
# Connecticut      False    False     False  False
# Delaware         False    False     False  False
# Florida          False    False     False  False
# Georgia          False    False     False  False
# Hawaii           False    False     False  False
# Idaho            False    False     False  False
# Illinois         False    False     False  False
# Indiana          False    False     False  False
# Iowa             False    False     False  False
# Kansas           False    False     False  False
# Kentucky         False    False     False  False
# ...

# %%
c_data.agg({'Murder': ['count','mean', 'min', 'max']})
# Out:
#        Murder
# count  50.000
# mean    7.788
# min     0.800
# max    17.400

# %%
c_data.agg({'Assault': ['count','mean', 'min', 'max']})
# Out:
#        Assault
# count    50.00
# mean    170.76
# min      45.00
# max     337.00

# %%
c_data.agg({'UrbanPop': ['count','mean', 'min', 'max']})
# Out:
#        UrbanPop
# count     50.00
# mean      65.54
# min       32.00
# max       91.00

# %%
c_data.agg({'Rape': ['count','mean', 'min', 'max']})
# Out:
#          Rape
# count  50.000
# mean   21.232
# min     7.300
# max    46.000

# %% [markdown]
# ### II)delete/ drop rows-10 to 15 of all columns

# %%
df1 = c_data
print(df1)
df1.drop(df1.iloc[10:16].index, inplace=True)
print(df1)
# Out:
#                 Murder  Assault  UrbanPop  Rape
# Alabama           13.2      236        58  21.2
# Alaska            10.0      263        48  44.5
# Arizona            8.1      294        80  31.0
# Arkansas           8.8      190        50  19.5
# California         9.0      276        91  40.6
# Colorado           7.9      204        78  38.7
# Connecticut        3.3      110        77  11.1
# Delaware           5.9      238        72  15.8
# Florida           15.4      335        80  31.9
# Georgia           17.4      211        60  25.8
# Hawaii             5.3       46        83  20.2
# Idaho              2.6      120        54  14.2
# Illinois          10.4      249        83  24.0
# Indiana            7.2      113        65  21.0
# Iowa               2.2       56        57  11.3
# Kansas             6.0      115        66  18.0
# Kentucky           9.7      109        52  16.3
# Louisiana         15.4      249        66  22.2
# Maine              2.1       83        51   7.8
# ...

# %% [markdown]
# ### III) Rename only one specific column in DF

# %%
df1.rename(columns={'UrbanPop':'Robbery'}, inplace=True)
df1.columns
# Out:
# Index(['Murder', 'Assault', 'Robbery', 'Rape'], dtype='object')

# %% [markdown]
# ### IV)After making changes, save the file( in your directory in Csv Format.

# %%
df1.to_csv('crimedata_newCreate.csv')

# %%
cdf = pd.read_csv('crimedata_newCreate.csv',index_col=0)
cdf
# Out:
#                 Murder  Assault  Robbery  Rape
# Alabama           13.2      236       58  21.2
# Alaska            10.0      263       48  44.5
# Arizona            8.1      294       80  31.0
# Arkansas           8.8      190       50  19.5
# California         9.0      276       91  40.6
# Colorado           7.9      204       78  38.7
# Connecticut        3.3      110       77  11.1
# Delaware           5.9      238       72  15.8
# Florida           15.4      335       80  31.9
# Georgia           17.4      211       60  25.8
# Kentucky           9.7      109       52  16.3
# Louisiana         15.4      249       66  22.2
# Maine              2.1       83       51   7.8
# Maryland          11.3      300       67  27.8
# Massachusetts      4.4      149       85  16.3
# Michigan          12.1      255       74  35.1
# Minnesota          2.7       72       66  14.9
# Mississippi       16.1      259       44  17.1
# Missouri           9.0      178       70  28.2
# ...
